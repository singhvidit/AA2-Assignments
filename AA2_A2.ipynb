# %% [markdown]
# # **Question-2**

# %%
#Question-2
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def sigma(x):
    return (5*6.65*(10**(-22))*(x**4))/((x**2 -1)**(2) + (x**6)/(10**4))

# Generate r values
x = np.linspace(0.0001, 2, 1000)

# Calculate corresponding y values
y = sigma(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\omega)$')
plt.xlabel(r'$\omega/\omega_0$ --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$\tau (\omega)$ --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\omega$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(0,2)
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-2
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def sigma(x):
    return (5*6.65*(10**(-22))*(x**4))/((x**2 -1)**(2) + (x**6)/(10**4))

# Generate r values
x = np.linspace(0.0001, 4, 1000)

# Calculate corresponding y values
y = sigma(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\omega)$')
plt.xlabel(r'$\omega/\omega_0$ --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$\tau (\omega)$ --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\omega$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(0.75,1.25)
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %% [markdown]
# # **Question-3**

# %%
#Question-3-(i)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def power(x):
    return 1.77*((10)**(-71))*np.exp(-4.80*((10)**(-11))*x/T)/np.sqrt(T)

# Generate r values
x = np.linspace(10**8, 10**(15), 10000)

# Calculate corresponding y values
temp = [1000, 10**5]
for T in temp:
  y = power(x)
  plt.plot(x, y, label= f"T={T} K")

# Plot the function
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$(dW/dVdtd\nu \bar{g}_{ff})$ (SI units)  --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Emission Power Spectrum for Thermal Distribution',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
#plt.xlim(0,0.2*10**(18))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %% [markdown]
# # **Question-4**

# %%
#Question-4-(i)-(a)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def tau(x):
    return 11.363*((10)**(-16))*L*(1 - np.exp(-4.80*((10)**(-11))*x/T))/(np.sqrt(T)*x*x*x)

# Generate r values
x = np.linspace(10**8, 10**(15), 10000)

# Calculate corresponding y values
T = 1000
L=100000
y = tau(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\nu)$')
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$(\tau (\nu)/\bar{g}_{ff})$  --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\nu$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(-0.01*10**(12),10**(12))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-4-(i)-(b)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def tau(x):
    return 11.363*((10)**(-16))*L*(1 - np.exp(-4.80*((10)**(-11))*x/T))/(np.sqrt(T)*x*x*x)

# Generate r values
x = np.linspace(10**8, 10**(15), 10000)

# Calculate corresponding y values
T = 1000
L = 10**(13)
y = tau(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\nu)$')
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$(\tau (\nu)/\bar{g}_{ff})$  --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\nu$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(-0.01*10**(12),10**(12))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-4-(ii)-(a)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def tau(x):
    return 11.363*((10)**(-16))*L*(1 - np.exp(-4.80*((10)**(-11))*x/T))/(np.sqrt(T)*x*x*x)

# Generate r values
x = np.linspace(10**8, 10**(15), 10000)

# Calculate corresponding y values
T = 100000
L=100000
y = tau(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\nu)$')
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$(\tau (\nu)/\bar{g}_{ff})$  --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\nu$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(-0.01*10**(12),10**(12))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-4-(ii)-(b)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def tau(x):
    return 11.363*((10)**(-16))*L*(1 - np.exp(-4.80*((10)**(-11))*x/T))/(np.sqrt(T)*x*x*x)

# Generate r values
x = np.linspace(10**8, 10**(15), 10000)

# Calculate corresponding y values
T = 100000
L = 10**(13)
y = tau(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\nu)$')
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$(\tau (\nu)/\bar{g}_{ff})$  --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\nu$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(-0.01*10**(12),10**(12))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %% [markdown]
# # **Question-6**

# %%
#Question-6-(a)-(i)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def power(x):
    return 1.94*((10)**(-42))*(x**(-3/4))*(B**(7/4))

# Generate r values
x = np.linspace(10**7, 10**(10), 10000)

# Calculate corresponding y values
B= 10**(-9)
y = power(x)

# Plot the function
plt.plot(x, y, label=r'$P_{tot} (\omega)$')
plt.xlabel(r'$\omega$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$P_{tot} (\omega)$ (Watts) --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Emitted Power ($P_{tot}$) vs Frequency ($\omega$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
#plt.xlim(-0.01*10**(12),10**(12))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-6-(a)-(ii)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def power(x):
    return 1.94*((10)**(-42))*(x**(-3/4))*(B**(7/4))

# Generate r values
x = np.linspace(10**7, 10**(10), 10000)

# Calculate corresponding y values
B= 10**(2)
y = power(x)

# Plot the function
plt.plot(x, y, label=r'$P_{tot} (\omega)$')
plt.xlabel(r'$\omega$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$P_{tot} (\omega)$ (Watts) --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Emitted Power ($P_{tot}$) vs Frequency ($\omega$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
#plt.xlim(-0.01*10**(12),10**(12))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-6-(a)-(iii)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def power(x):
    return 1.94*((10)**(-42))*(x**(-3/4))*(B**(7/4))

# Generate r values
x = np.linspace(10**7, 10**(10), 10000)

# Calculate corresponding y values
B= 10**(2)
y = power(x)

# Plot the function
plt.plot(x, y, label=r'$P_{tot} (\omega)$')
plt.xlabel(r'$\omega$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$P_{tot} (\omega)$ (Watts) --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Emitted Power ($P_{tot}$) vs Frequency ($\omega$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
#plt.xlim(-0.01*10**(12),10**(12))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-6-(b)-(i)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def power(x):
    return 3.03*(x**(-3/2))*(B**(5/2))*((10)**(-40))

# Generate r values
x = np.linspace(10**(10), 10**(12), 10000)

# Calculate corresponding y values
B= 10**(-9)
y = power(x)

# Plot the function
plt.plot(x, y, label=r'$P_{tot} (\omega)$')
plt.xlabel(r'$\omega$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$P_{tot} (\omega)$ (Watts) --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Emitted Power ($P_{tot}$) vs Frequency ($\omega$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
#plt.xlim(-0.01*10**(12),10**(12))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-6-(b)-(ii)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def power(x):
    return 3.03*(x**(-3/2))*(B**(5/2))*((10)**(-40))

# Generate r values
x = np.linspace(10**(10), 10**(12), 10000)

# Calculate corresponding y values
B= 10**(2)
y = power(x)

# Plot the function
plt.plot(x, y, label=r'$P_{tot} (\omega)$')
plt.xlabel(r'$\omega$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$P_{tot} (\omega)$ (Watts) --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Emitted Power ($P_{tot}$) vs Frequency ($\omega$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
#plt.xlim(-0.01*10**(12),10**(12))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-6-(b)-(iii)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def power(x):
    return 3.03*(x**(-3/2))*(B**(5/2))*((10)**(-40))

# Generate r values
x = np.linspace(10**(10), 10**(12), 10000)

# Calculate corresponding y values
B= 10**(2)
y = power(x)

# Plot the function
plt.plot(x, y, label=r'$P_{tot} (\omega)$')
plt.xlabel(r'$\omega$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$P_{tot} (\omega)$ (Watts) --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Emitted Power ($P_{tot}$) vs Frequency ($\omega$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
#plt.xlim(-0.01*10**(12),10**(12))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %% [markdown]
# # **Question-7**

# %%
#Question-7-(a)-(A)-(i)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def sigma(x):
    return 2.804*(x**(-13/4))*(B**(9/4))*((10)**(8))*L

# Generate r values
x = np.linspace(10**7, 10**(10), 10000)

# Calculate corresponding y values
L=10**5
B=10**(-9)
y = sigma(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\nu)$')
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$\tau (\nu)$ --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\nu$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(0,0.2*((10)**(9)))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-7-(a)-(A)-(ii)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def sigma(x):
    return 2.804*(x**(-13/4))*(B**(9/4))*((10)**(8))*L

# Generate r values
x = np.linspace(10**7, 10**(10), 10000)

# Calculate corresponding y values
L=10**5
B=10**(2)
y = sigma(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\nu)$')
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$\tau (\nu)$ --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\nu$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(0,0.2*((10)**(9)))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-7-(a)-(A)-(iii)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def sigma(x):
    return 2.804*(x**(-13/4))*(B**(9/4))*((10)**(8))*L

# Generate r values
x = np.linspace(10**7, 10**(10), 10000)

# Calculate corresponding y values
L=10**5
B=10**(2)
y = sigma(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\nu)$')
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$\tau (\nu)$ --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\nu$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(0,0.2*((10)**(9)))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-7-(a)-(B)-(i)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def sigma(x):
    return 2.804*(x**(-13/4))*(B**(9/4))*((10)**(8))*L

# Generate r values
x = np.linspace(10**7, 10**(10), 10000)

# Calculate corresponding y values
L=10**(13)
B=10**(-9)
y = sigma(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\nu)$')
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$\tau (\nu)$ --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\nu$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(0,0.2*((10)**(9)))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-7-(a)-(B)-(ii)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def sigma(x):
    return 2.804*(x**(-13/4))*(B**(9/4))*((10)**(8))*L

# Generate r values
x = np.linspace(10**7, 10**(10), 10000)

# Calculate corresponding y values
L=10**(13)
B=10**(2)
y = sigma(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\nu)$')
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$\tau (\nu)$ --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\nu$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(0,0.2*((10)**(9)))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-7-(a)-(B)-(iii)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def sigma(x):
    return 2.804*(x**(-13/4))*(B**(9/4))*((10)**(8))*L

# Generate r values
x = np.linspace(10**7, 10**(10), 10000)

# Calculate corresponding y values
L=10**(13)
B=10**(2)
y = sigma(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\nu)$')
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$\tau (\nu)$ --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\nu$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(0,0.2*((10)**(9)))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-7-(b)-(A)-(i)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def sigma(x):
    return 8.638*(x**(-4))*(B**(3))*((10)**(29))*L

# Generate r values
x = np.linspace(10**(10), 10**(12), 10000)

# Calculate corresponding y values
L=10**(5)
B=10**(-9)
y = sigma(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\nu)$')
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$\tau (\nu)$ --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\nu$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(0,3*((10)**(11)))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-7-(b)-(A)-(ii)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def sigma(x):
    return 8.638*(x**(-4))*(B**(3))*((10)**(29))*L

# Generate r values
x = np.linspace(10**(10), 10**(12), 10000)

# Calculate corresponding y values
L=10**(5)
B=10**(2)
y = sigma(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\nu)$')
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$\tau (\nu)$ --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\nu$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(0,3*((10)**(11)))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-7-(b)-(A)-(iii)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def sigma(x):
    return 8.638*(x**(-4))*(B**(3))*((10)**(29))*L

# Generate r values
x = np.linspace(10**(10), 10**(12), 10000)

# Calculate corresponding y values
L=10**(5)
B=10**(2)
y = sigma(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\nu)$')
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$\tau (\nu)$ --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\nu$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(0,3*((10)**(11)))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-7-(b)-(B)-(i)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def sigma(x):
    return 8.638*(x**(-4))*(B**(3))*((10)**(29))*L

# Generate r values
x = np.linspace(10**(10), 10**(12), 10000)

# Calculate corresponding y values
L=10**(13)
B=10**(-9)
y = sigma(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\nu)$')
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$\tau (\nu)$ --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\nu$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(0,3*((10)**(11)))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-7-(b)-(B)-(ii)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def sigma(x):
    return 8.638*(x**(-4))*(B**(3))*((10)**(29))*L

# Generate r values
x = np.linspace(10**(10), 10**(12), 10000)

# Calculate corresponding y values
L=10**(13)
B=10**(2)
y = sigma(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\nu)$')
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$\tau (\nu)$ --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\nu$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(0,3*((10)**(11)))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot

# %%
#Question-7-(b)-(B)-(iii)
import numpy as np
import matplotlib.pyplot as plt

# Define the function to be plotted
def sigma(x):
    return 8.638*(x**(-4))*(B**(3))*((10)**(29))*L

# Generate r values
x = np.linspace(10**(10), 10**(12), 10000)

# Calculate corresponding y values
L=10**(13)
B=10**(2)
y = sigma(x)

# Plot the function
plt.plot(x, y, label=r'$\tau (\nu)$')
plt.xlabel(r'$\nu$ (Hz) --->',rotation = 0, fontsize = 15 , labelpad = 4)  # Label for x-axis
plt.ylabel(r'$\tau (\nu)$ --->',rotation = 90, fontsize = 15 , labelpad = 4)  # Label for y-axis
plt.title(r'Optical Depth ($\tau$) vs Frequency ($\nu$)',fontsize = 20)  # Title of the plot
#plt.ylim(0,4)
plt.xlim(0,3*((10)**(11)))
plt.rcParams['figure.figsize'] = [10,7]
plt.tick_params(axis="y",direction="in", pad=6)
plt.tick_params(axis="x",direction="in", pad=6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)  # Enable grid
plt.legend(edgecolor = 'black', fontsize=15)  # Show legend
plt.show()  # Show the plot
